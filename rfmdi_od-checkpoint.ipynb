# %%
import cv2
import threading
import math
from ultralytics import YOLO
import time
import requests

# %%
rtsp_url = "rtsp://admin:admin123456@172.20.10.3:8554/profile0"
model = YOLO("my_model/best_v2.pt")
classNames = ['Red', 'Orange', 'Yellow', 'Board']
detected_classes = set()
detected_label = set()
detected_index = set()

frame_read_successful = threading.Event()

# %%
def sendAlarm(color,time):
    url = f'http://localhost:8000/api/alarm/{color}/{time}'
    response = requests.get(url)
    if response.status_code == 200:
        print(f"alarm Sent: {color}")
    else:
        print("alarm cannot send")

def capture_frames(cap, window_name, interval=0.5):
    is_yellow_detected=False;
    is_orange_detected=False;
    is_red_detected=False;

    start_time = time.time()
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(window_name, 400, 400)
    

    try:
        while True:
            success, img = cap.read()
            frame_read_successful.set() if success else frame_read_successful.clear()

            if not success:
                print(f"Failed to read from {window_name}")
                break

            current_time = time.time()
            alarm_time = time.time()
            if current_time - start_time >= interval:
                        
                results = model(img, stream=True)
                detected_classes.clear()
                detected_index.clear()
                detected_label.clear()

                for r in results:
                    for box in r.boxes:
                        x1, y1, x2, y2 = map(int, box.xyxy[0])
                        confidence = math.ceil((box.conf[0] * 100)) / 100
                        
                        cls = int(box.cls[0])
                        detected_index.add(cls)

                        #label = f"{classNames[cls]}: {confidence}"
                        label = f"{classNames[cls]}"            
                        detected_classes.add((label, (x1, y1, x2, y2)))

                for item in detected_classes:
                    stored_label = item[0]
                    stored_box = item[1]
                    
                    board_bbox = None
                    for label, bbox in detected_classes:
                        if label == "Board":
                            board_bbox = bbox
                            break
                            
                if board_bbox:
                    # Check each item in detected_classes
                    for label, bbox in detected_classes:
                        
                        xx1, yy1, xx2, yy2 = bbox
                        if label == "Board":
                            cv2.rectangle(img, (xx1, yy1), (xx2, yy2), (255, 0, 255), 2)

                        # Check if bbox is inside board_bbox
                        board_x1, board_y1, board_x2, board_y2 = board_bbox
                        if (xx1 >= board_x1 and yy1 >= board_y1 and xx2 <= board_x2 and yy2 <= board_y2):
                            detected_label.add(label)
                            detected_index.add(cls)
                                
                            cv2.rectangle(img, (xx1, yy1), (xx2, yy2), (255, 0, 255), 2)
                            cv2.putText(img, label, (xx1, yy1), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
                            
                all_class_index = set(range(len(classNames)))
                missing_class_index = all_class_index - detected_index
                missing_class_names = [classNames[cls] for cls in missing_class_index]
            
                if any("Board" in item for item in detected_classes):                             
                    if missing_class_names:
                        if missing_class_names[0] == "Yellow" and not is_yellow_detected:
                            print('M yellow')
                            is_yellow_detected = True
                            sendAlarm("Yellow", 60)
                        elif missing_class_names[0] == "Orange" and not is_orange_detected:
                            print('M orange')
                            is_orange_detected = True
                            sendAlarm("Orange", 120)
                        elif missing_class_names[0] == "Red" and not is_red_detected:
                            print('M red')
                            is_red_detected = True
                            sendAlarm("Red", 180)
                            
                    else:
                        print("All present.")
                else:
                    print("Board not detected")
                start_time = current_time  # Reset the timer

                
 
            cv2.imshow(window_name, img)
            if cv2.waitKey(1) == ord('q'):
                break
            time.sleep(0.01)  # Small delay to prevent 100% CPU usage
    finally:
        cap.release()
        cv2.destroyAllWindows()

def monitor_stream(timeout):
    global frame_read_successful
    while True:
        time.sleep(timeout)
        if not frame_read_successful.is_set():
            print("Stream timeout. Attempting to reconnect...")
            return  # Exit the monitor thread to trigger reconnection

def start_capture():
    global frame_read_successful
    while True:
        cap = cv2.VideoCapture(rtsp_url)
        #cap = cv2.VideoCapture(1)
        #cap = cv2.VideoCapture('./video/t5.mov')
        if cap.isOpened():
            frame_read_successful.set()
            monitor_thread = threading.Thread(target=monitor_stream, args=(5,))
            monitor_thread.start()

            capture_frames(cap, "Camera")

            monitor_thread.join()  # Wait for the monitor thread to finish

        else:
            print("Error: Could not open video stream. Retrying in 5 seconds...")
            time.sleep(5)  # Wait before retrying

# %%
capture_thread = threading.Thread(target=start_capture)
capture_thread.start()
capture_thread.join()
# Out:
# 0: 384x640 1 Red, 196.9ms
# Speed: 21.8ms preprocess, 196.9ms inference, 1203.8ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 185.2ms
# Speed: 10.3ms preprocess, 185.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 200.4ms
# Speed: 4.6ms preprocess, 200.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 226.8ms
# Speed: 5.0ms preprocess, 226.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 225.0ms
# Speed: 3.8ms preprocess, 225.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 177.9ms
# Speed: 2.0ms preprocess, 177.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 198.0ms
# Speed: 3.5ms preprocess, 198.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 235.0ms
# Speed: 5.2ms preprocess, 235.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 204.4ms
# Speed: 4.1ms preprocess, 204.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 257.9ms
# Speed: 5.5ms preprocess, 257.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 208.7ms
# Speed: 5.0ms preprocess, 208.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 239.9ms
# Speed: 5.1ms preprocess, 239.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 295.0ms
# Speed: 4.9ms preprocess, 295.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 300.8ms
# Speed: 0.0ms preprocess, 300.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 290.0ms
# Speed: 5.2ms preprocess, 290.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 289.3ms
# Speed: 5.0ms preprocess, 289.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 304.4ms
# Speed: 3.6ms preprocess, 304.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 320.1ms
# Speed: 0.0ms preprocess, 320.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 337.1ms
# Speed: 7.1ms preprocess, 337.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 257.4ms
# Speed: 2.2ms preprocess, 257.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 399.0ms
# Speed: 5.3ms preprocess, 399.0ms inference, 13.8ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 652.8ms
# Speed: 8.2ms preprocess, 652.8ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 390.6ms
# Speed: 8.1ms preprocess, 390.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 312.9ms
# Speed: 8.1ms preprocess, 312.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 341.3ms
# Speed: 2.5ms preprocess, 341.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 320.2ms
# Speed: 9.7ms preprocess, 320.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 286.9ms
# Speed: 0.0ms preprocess, 286.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 318.1ms
# Speed: 0.0ms preprocess, 318.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 340.8ms
# Speed: 4.9ms preprocess, 340.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 290.5ms
# Speed: 6.2ms preprocess, 290.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 291.3ms
# Speed: 3.0ms preprocess, 291.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 294.8ms
# Speed: 1.7ms preprocess, 294.8ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 281.0ms
# Speed: 8.2ms preprocess, 281.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 289.0ms
# Speed: 3.5ms preprocess, 289.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 289.7ms
# Speed: 7.8ms preprocess, 289.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 702.4ms
# Speed: 9.3ms preprocess, 702.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 488.0ms
# Speed: 8.2ms preprocess, 488.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 504.0ms
# Speed: 10.4ms preprocess, 504.0ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 571.6ms
# Speed: 8.4ms preprocess, 571.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 532.6ms
# Speed: 8.2ms preprocess, 532.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 532.7ms
# Speed: 8.3ms preprocess, 532.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 621.4ms
# Speed: 0.0ms preprocess, 621.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 520.3ms
# Speed: 8.6ms preprocess, 520.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 438.8ms
# Speed: 5.6ms preprocess, 438.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 383.7ms
# Speed: 10.0ms preprocess, 383.7ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 330.3ms
# Speed: 2.0ms preprocess, 330.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 472.9ms
# Speed: 6.3ms preprocess, 472.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 332.6ms
# Speed: 2.5ms preprocess, 332.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 446.3ms
# Speed: 9.3ms preprocess, 446.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 340.4ms
# Speed: 39.9ms preprocess, 340.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 398.0ms
# Speed: 21.5ms preprocess, 398.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 418.5ms
# Speed: 6.8ms preprocess, 418.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 523.0ms
# Speed: 10.1ms preprocess, 523.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 560.7ms
# Speed: 10.2ms preprocess, 560.7ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 249.8ms
# Speed: 6.8ms preprocess, 249.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 236.2ms
# Speed: 0.0ms preprocess, 236.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 187.1ms
# Speed: 3.3ms preprocess, 187.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 180.9ms
# Speed: 8.1ms preprocess, 180.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 195.3ms
# Speed: 4.5ms preprocess, 195.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 198.5ms
# Speed: 10.5ms preprocess, 198.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 161.6ms
# Speed: 3.2ms preprocess, 161.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 172.6ms
# Speed: 7.8ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 169.1ms
# Speed: 1.6ms preprocess, 169.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 215.4ms
# Speed: 10.0ms preprocess, 215.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 181.5ms
# Speed: 8.4ms preprocess, 181.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 187.5ms
# Speed: 0.0ms preprocess, 187.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 190.4ms
# Speed: 0.0ms preprocess, 190.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 188.2ms
# Speed: 5.6ms preprocess, 188.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 200.0ms
# Speed: 3.4ms preprocess, 200.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 183.7ms
# Speed: 7.5ms preprocess, 183.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 209.2ms
# Speed: 9.0ms preprocess, 209.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 179.1ms
# Speed: 1.0ms preprocess, 179.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 180.1ms
# Speed: 2.5ms preprocess, 180.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 190.1ms
# Speed: 5.5ms preprocess, 190.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 177.5ms
# Speed: 7.9ms preprocess, 177.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 179.6ms
# Speed: 0.0ms preprocess, 179.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 179.9ms
# Speed: 0.0ms preprocess, 179.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 179.6ms
# Speed: 6.9ms preprocess, 179.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 162.1ms
# Speed: 4.1ms preprocess, 162.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 180.8ms
# Speed: 8.9ms preprocess, 180.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 172.5ms
# Speed: 0.5ms preprocess, 172.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 192.6ms
# Speed: 0.0ms preprocess, 192.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 180.6ms
# Speed: 0.0ms preprocess, 180.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 178.8ms
# Speed: 0.0ms preprocess, 178.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 186.0ms
# Speed: 0.0ms preprocess, 186.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 168.2ms
# Speed: 3.0ms preprocess, 168.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 174.7ms
# Speed: 0.0ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 165.2ms
# Speed: 6.3ms preprocess, 165.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 187.4ms
# Speed: 3.1ms preprocess, 187.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 177.5ms
# Speed: 3.3ms preprocess, 177.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 (no detections), 158.3ms
# Speed: 6.8ms preprocess, 158.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 181.6ms
# Speed: 3.8ms preprocess, 181.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 180.2ms
# Speed: 9.9ms preprocess, 180.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 233.8ms
# Speed: 0.9ms preprocess, 233.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 173.3ms
# Speed: 1.9ms preprocess, 173.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 185.2ms
# Speed: 0.0ms preprocess, 185.2ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 174.0ms
# Speed: 3.1ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Board not detected
#
# 0: 384x640 1 Red, 1 Board, 184.2ms
# Speed: 1.0ms preprocess, 184.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# M orange
# alarm Sent: Orange
