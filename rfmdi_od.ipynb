# %%
import cv2
import threading
import math
from ultralytics import YOLO
import time
import requests

# %%
rtsp_url = "rtsp://admin:admin123456@172.20.10.3:8554/profile0"
model = YOLO("my_model/best_v2.pt")
classNames = ['Red', 'Orange', 'Yellow', 'Board']
detected_classes = set()
detected_label = set()
detected_index = set()

frame_read_successful = threading.Event()

# %%
def sendAlarm(color,time):
    url = f'http://localhost:8000/api/alarm/{color}/{time}'
    response = requests.get(url)
    if response.status_code == 200:
        print(f"alarm Sent: {color}")
    else:
        print("alarm cannot send")

def capture_frames(cap, window_name, interval=0.5):
    is_yellow_detected=False;
    is_orange_detected=False;
    is_red_detected=False;

    start_time = time.time()
    cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
    cv2.resizeWindow(window_name, 400, 400)
    

    try:
        while True:
            success, img = cap.read()
            frame_read_successful.set() if success else frame_read_successful.clear()

            if not success:
                print(f"Failed to read from {window_name}")
                break

            current_time = time.time()
            alarm_time = time.time()
            if current_time - start_time >= interval:
                        
                results = model(img, stream=True)
                detected_classes.clear()
                detected_index.clear()
                detected_label.clear()

                for r in results:
                    for box in r.boxes:
                        x1, y1, x2, y2 = map(int, box.xyxy[0])
                        confidence = math.ceil((box.conf[0] * 100)) / 100
                        
                        cls = int(box.cls[0])
                        detected_index.add(cls)

                        #label = f"{classNames[cls]}: {confidence}"
                        label = f"{classNames[cls]}"            
                        detected_classes.add((label, (x1, y1, x2, y2)))

                for item in detected_classes:
                    stored_label = item[0]
                    stored_box = item[1]
                    
                    board_bbox = None
                    for label, bbox in detected_classes:
                        if label == "Board":
                            board_bbox = bbox
                            break
                            
                if board_bbox:
                    # Check each item in detected_classes
                    for label, bbox in detected_classes:
                        
                        xx1, yy1, xx2, yy2 = bbox
                        if label == "Board":
                            cv2.rectangle(img, (xx1, yy1), (xx2, yy2), (255, 0, 255), 2)

                        # Check if bbox is inside board_bbox
                        board_x1, board_y1, board_x2, board_y2 = board_bbox
                        if (xx1 >= board_x1 and yy1 >= board_y1 and xx2 <= board_x2 and yy2 <= board_y2):
                            detected_label.add(label)
                            detected_index.add(cls)
                                
                            cv2.rectangle(img, (xx1, yy1), (xx2, yy2), (255, 0, 255), 2)
                            cv2.putText(img, label, (xx1, yy1), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
                            
                all_class_index = set(range(len(classNames)))
                missing_class_index = all_class_index - detected_index
                missing_class_names = [classNames[cls] for cls in missing_class_index]
            
                if any("Board" in item for item in detected_classes):                             
                    if missing_class_names:
                        if missing_class_names[0] == "Yellow" and not is_yellow_detected:
                            print('M yellow')
                            is_yellow_detected = True
                            sendAlarm("Yellow", 60)
                        elif missing_class_names[0] == "Orange" and not is_orange_detected:
                            print('M orange')
                            is_orange_detected = True
                            sendAlarm("Orange", 120)
                        elif missing_class_names[0] == "Red" and not is_red_detected:
                            print('M red')
                            is_red_detected = True
                            sendAlarm("Red", 180)
                            
                    else:
                        print("All present.")
                else:
                    print("Board not detected")
                start_time = current_time  # Reset the timer

                
 
            cv2.imshow(window_name, img)
            if cv2.waitKey(1) == ord('q'):
                break
            time.sleep(0.01)  # Small delay to prevent 100% CPU usage
    finally:
        cap.release()
        cv2.destroyAllWindows()

def monitor_stream(timeout):
    global frame_read_successful
    while True:
        time.sleep(timeout)
        if not frame_read_successful.is_set():
            print("Stream timeout. Attempting to reconnect...")
            return  # Exit the monitor thread to trigger reconnection

def start_capture():
    global frame_read_successful
    while True:
        #cap = cv2.VideoCapture(rtsp_url)
        cap = cv2.VideoCapture(1)
        #cap = cv2.VideoCapture('./video/t5.mov')
        if cap.isOpened():
            frame_read_successful.set()
            monitor_thread = threading.Thread(target=monitor_stream, args=(5,))
            monitor_thread.start()

            capture_frames(cap, "Camera")

            monitor_thread.join()  # Wait for the monitor thread to finish

        else:
            print("Error: Could not open video stream. Retrying in 5 seconds...")
            time.sleep(5)  # Wait before retrying

# %%
capture_thread = threading.Thread(target=start_capture)
capture_thread.start()
capture_thread.join()
# Out:
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 125.3ms
# Speed: 0.0ms preprocess, 125.3ms inference, 608.5ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 105.9ms
# Speed: 3.1ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 115.9ms
# Speed: 4.4ms preprocess, 115.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 120.2ms
# Speed: 0.0ms preprocess, 120.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 122.4ms
# Speed: 0.0ms preprocess, 122.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 101.9ms
# Speed: 2.3ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 116.1ms
# Speed: 2.8ms preprocess, 116.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 118.0ms
# Speed: 5.4ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 113.4ms
# Speed: 2.5ms preprocess, 113.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 116.3ms
# Speed: 5.8ms preprocess, 116.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 114.6ms
# Speed: 4.5ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 116.2ms
# Speed: 4.1ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 113.2ms
# Speed: 4.7ms preprocess, 113.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 115.3ms
# Speed: 4.1ms preprocess, 115.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 385.2ms
# Speed: 3.2ms preprocess, 385.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 403.7ms
# Speed: 7.2ms preprocess, 403.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 394.1ms
# Speed: 5.8ms preprocess, 394.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 402.5ms
# Speed: 11.8ms preprocess, 402.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 384.9ms
# Speed: 4.5ms preprocess, 384.9ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 392.5ms
# Speed: 6.4ms preprocess, 392.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 447.3ms
# Speed: 6.8ms preprocess, 447.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 233.5ms
# Speed: 4.8ms preprocess, 233.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 279.5ms
# Speed: 4.7ms preprocess, 279.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 428.6ms
# Speed: 3.6ms preprocess, 428.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 384.1ms
# Speed: 6.2ms preprocess, 384.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 452.9ms
# Speed: 4.9ms preprocess, 452.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 424.8ms
# Speed: 10.0ms preprocess, 424.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 419.9ms
# Speed: 9.1ms preprocess, 419.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 364.0ms
# Speed: 6.1ms preprocess, 364.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.6ms
# Speed: 6.1ms preprocess, 399.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 182.4ms
# Speed: 8.0ms preprocess, 182.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 157.9ms
# Speed: 4.7ms preprocess, 157.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 138.7ms
# Speed: 2.2ms preprocess, 138.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 124.6ms
# Speed: 3.3ms preprocess, 124.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 111.0ms
# Speed: 1.2ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 108.5ms
# Speed: 3.4ms preprocess, 108.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 111.2ms
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 117.0ms
# Speed: 3.1ms preprocess, 117.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 126.4ms
# Speed: 0.0ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 124.2ms
# Speed: 2.3ms preprocess, 124.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 105.1ms
# Speed: 3.2ms preprocess, 105.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 115.5ms
# Speed: 4.1ms preprocess, 115.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.3ms
# Speed: 0.0ms preprocess, 111.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 109.3ms
# Speed: 0.0ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Board, 116.7ms
# Speed: 0.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# M yellow
# alarm Sent: Yellow
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 122.6ms
# Speed: 0.0ms preprocess, 122.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 103.3ms
# Speed: 0.0ms preprocess, 103.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 111.8ms
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 114.4ms
# Speed: 0.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.9ms
# Speed: 0.0ms preprocess, 113.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.3ms
# Speed: 0.0ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.3ms
# Speed: 0.0ms preprocess, 118.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 124.3ms
# Speed: 0.0ms preprocess, 124.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.8ms
# Speed: 0.0ms preprocess, 112.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.3ms
# Speed: 0.0ms preprocess, 118.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.1ms
# Speed: 0.0ms preprocess, 119.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.2ms
# Speed: 0.0ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.4ms
# Speed: 0.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.4ms
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.2ms
# Speed: 0.0ms preprocess, 104.2ms inference, 14.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.3ms
# Speed: 3.8ms preprocess, 111.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 170.3ms
# Speed: 0.0ms preprocess, 170.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 115.6ms
# Speed: 2.4ms preprocess, 115.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 191.0ms
# Speed: 3.4ms preprocess, 191.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 134.4ms
# Speed: 0.0ms preprocess, 134.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 143.7ms
# Speed: 0.0ms preprocess, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 156.7ms
# Speed: 0.0ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 171.0ms
# Speed: 0.0ms preprocess, 171.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 169.1ms
# Speed: 3.1ms preprocess, 169.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 135.0ms
# Speed: 5.0ms preprocess, 135.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 361.4ms
# Speed: 0.0ms preprocess, 361.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 483.3ms
# Speed: 4.3ms preprocess, 483.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 389.9ms
# Speed: 4.0ms preprocess, 389.9ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 382.8ms
# Speed: 5.0ms preprocess, 382.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 398.3ms
# Speed: 0.0ms preprocess, 398.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 408.9ms
# Speed: 4.6ms preprocess, 408.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 409.0ms
# Speed: 4.1ms preprocess, 409.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 406.4ms
# Speed: 1.3ms preprocess, 406.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 482.7ms
# Speed: 3.1ms preprocess, 482.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 402.0ms
# Speed: 0.0ms preprocess, 402.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 417.7ms
# Speed: 5.5ms preprocess, 417.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 377.4ms
# Speed: 1.0ms preprocess, 377.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 352.0ms
# Speed: 4.5ms preprocess, 352.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 381.3ms
# Speed: 3.0ms preprocess, 381.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 384.4ms
# Speed: 0.0ms preprocess, 384.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 406.7ms
# Speed: 7.0ms preprocess, 406.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 203.0ms
# Speed: 5.9ms preprocess, 203.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.2ms
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.8ms
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.2ms
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.9ms
# Speed: 0.0ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.6ms
# Speed: 1.1ms preprocess, 110.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.7ms
# Speed: 0.0ms preprocess, 119.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 123.7ms
# Speed: 0.0ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.1ms
# Speed: 0.0ms preprocess, 107.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 105.9ms
# Speed: 2.1ms preprocess, 105.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 103.8ms
# Speed: 0.0ms preprocess, 103.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.9ms
# Speed: 0.0ms preprocess, 118.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 108.4ms
# Speed: 0.0ms preprocess, 108.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 105.3ms
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 121.1ms
# Speed: 0.0ms preprocess, 121.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.3ms
# Speed: 0.0ms preprocess, 117.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 122.3ms
# Speed: 0.0ms preprocess, 122.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.6ms
# Speed: 0.0ms preprocess, 109.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 124.5ms
# Speed: 0.0ms preprocess, 124.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 102.8ms
# Speed: 4.0ms preprocess, 102.8ms inference, 14.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 115.0ms
# Speed: 0.0ms preprocess, 115.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.8ms
# Speed: 3.8ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 100.3ms
# Speed: 0.5ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 120.1ms
# Speed: 0.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 102.9ms
# Speed: 0.0ms preprocess, 102.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.6ms
# Speed: 0.0ms preprocess, 110.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 1 Orange, 1 Yellow, 2 Boards, 108.2ms
# Speed: 3.0ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 1 Board, 113.4ms
# Speed: 0.0ms preprocess, 113.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# M orange
# alarm Sent: Orange
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 110.5ms
# Speed: 0.0ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 115.4ms
# Speed: 0.0ms preprocess, 115.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.7ms
# Speed: 0.0ms preprocess, 119.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 115.2ms
# Speed: 3.5ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.4ms
# Speed: 3.2ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.9ms
# Speed: 0.0ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.4ms
# Speed: 5.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.7ms
# Speed: 0.0ms preprocess, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 128.4ms
# Speed: 0.0ms preprocess, 128.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.9ms
# Speed: 5.0ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.4ms
# Speed: 0.0ms preprocess, 119.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.6ms
# Speed: 2.2ms preprocess, 118.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.5ms
# Speed: 0.0ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.9ms
# Speed: 2.1ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.5ms
# Speed: 0.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.3ms
# Speed: 0.0ms preprocess, 117.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.0ms
# Speed: 0.0ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.7ms
# Speed: 0.0ms preprocess, 104.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 117.0ms
# Speed: 0.0ms preprocess, 117.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.7ms
# Speed: 2.6ms preprocess, 107.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.1ms
# Speed: 4.3ms preprocess, 116.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 123.1ms
# Speed: 0.0ms preprocess, 123.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.8ms
# Speed: 4.5ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 123.6ms
# Speed: 0.0ms preprocess, 123.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.0ms
# Speed: 0.0ms preprocess, 118.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.7ms
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 120.2ms
# Speed: 0.0ms preprocess, 120.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.1ms
# Speed: 0.0ms preprocess, 116.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 117.7ms
# Speed: 0.0ms preprocess, 117.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.3ms
# Speed: 2.1ms preprocess, 104.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 109.8ms
# Speed: 0.0ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.2ms
# Speed: 0.0ms preprocess, 118.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.5ms
# Speed: 0.0ms preprocess, 113.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.0ms
# Speed: 0.0ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 120.1ms
# Speed: 0.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.2ms
# Speed: 0.0ms preprocess, 112.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.3ms
# Speed: 0.0ms preprocess, 117.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 122.4ms
# Speed: 1.7ms preprocess, 122.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.5ms
# Speed: 2.3ms preprocess, 110.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.7ms
# Speed: 0.0ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.0ms
# Speed: 0.0ms preprocess, 113.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 114.2ms
# Speed: 0.0ms preprocess, 114.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 108.0ms
# Speed: 0.0ms preprocess, 108.0ms inference, 15.1ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 127.6ms
# Speed: 0.0ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 105.3ms
# Speed: 0.0ms preprocess, 105.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 108.1ms
# Speed: 0.0ms preprocess, 108.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.1ms
# Speed: 0.0ms preprocess, 118.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 118.0ms
# Speed: 0.0ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.1ms
# Speed: 0.0ms preprocess, 111.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.7ms
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 106.7ms
# Speed: 0.0ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 115.9ms
# Speed: 0.0ms preprocess, 115.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.0ms
# Speed: 5.6ms preprocess, 110.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 114.6ms
# Speed: 4.4ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 127.9ms
# Speed: 0.0ms preprocess, 127.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 101.9ms
# Speed: 2.9ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.8ms
# Speed: 5.4ms preprocess, 104.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 106.1ms
# Speed: 3.3ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 127.8ms
# Speed: 0.0ms preprocess, 127.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.0ms
# Speed: 0.0ms preprocess, 118.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.9ms
# Speed: 0.0ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.5ms
# Speed: 0.0ms preprocess, 117.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.0ms
# Speed: 0.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.5ms
# Speed: 0.0ms preprocess, 116.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.7ms
# Speed: 0.0ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.2ms
# Speed: 0.0ms preprocess, 113.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.3ms
# Speed: 0.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.0ms
# Speed: 0.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 111.5ms
# Speed: 0.0ms preprocess, 111.5ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 125.9ms
# Speed: 0.0ms preprocess, 125.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.7ms
# Speed: 0.0ms preprocess, 119.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.3ms
# Speed: 0.0ms preprocess, 113.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 113.4ms
# Speed: 0.0ms preprocess, 113.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.0ms
# Speed: 0.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.3ms
# Speed: 0.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.0ms
# Speed: 2.6ms preprocess, 112.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.4ms
# Speed: 0.0ms preprocess, 107.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 119.5ms
# Speed: 0.0ms preprocess, 119.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.9ms
# Speed: 0.0ms preprocess, 113.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 108.3ms
# Speed: 0.0ms preprocess, 108.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 107.6ms
# Speed: 4.0ms preprocess, 107.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.3ms
# Speed: 2.7ms preprocess, 112.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 108.2ms
# Speed: 3.1ms preprocess, 108.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.8ms
# Speed: 2.6ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 114.3ms
# Speed: 0.0ms preprocess, 114.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 125.8ms
# Speed: 0.0ms preprocess, 125.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 118.7ms
# Speed: 0.0ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.8ms
# Speed: 0.0ms preprocess, 117.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 112.4ms
# Speed: 0.0ms preprocess, 112.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 120.3ms
# Speed: 0.0ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.2ms
# Speed: 0.0ms preprocess, 116.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 109.3ms
# Speed: 0.0ms preprocess, 109.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 117.5ms
# Speed: 0.0ms preprocess, 117.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 112.5ms
# Speed: 0.0ms preprocess, 112.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.1ms
# Speed: 0.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 106.2ms
# Speed: 0.0ms preprocess, 106.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 116.4ms
# Speed: 0.0ms preprocess, 116.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 102.8ms
# Speed: 1.8ms preprocess, 102.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 113.1ms
# Speed: 2.6ms preprocess, 113.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 116.8ms
# Speed: 0.0ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.7ms
# Speed: 0.0ms preprocess, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.6ms
# Speed: 0.0ms preprocess, 117.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 114.7ms
# Speed: 0.0ms preprocess, 114.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.8ms
# Speed: 0.0ms preprocess, 110.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 109.1ms
# Speed: 0.0ms preprocess, 109.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 109.0ms
# Speed: 0.0ms preprocess, 109.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 106.8ms
# Speed: 4.1ms preprocess, 106.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 114.6ms
# Speed: 0.0ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.0ms
# Speed: 4.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.2ms
# Speed: 0.0ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 103.9ms
# Speed: 0.0ms preprocess, 103.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 117.8ms
# Speed: 0.0ms preprocess, 117.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 113.8ms
# Speed: 0.0ms preprocess, 113.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 117.6ms
# Speed: 0.0ms preprocess, 117.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 102.1ms
# Speed: 3.9ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.1ms
# Speed: 0.0ms preprocess, 111.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 110.3ms
# Speed: 0.0ms preprocess, 110.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 104.6ms
# Speed: 0.0ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 1 Board, 111.4ms
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 105.5ms
# Speed: 3.0ms preprocess, 105.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.6ms
# Speed: 0.0ms preprocess, 113.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 120.8ms
# Speed: 0.0ms preprocess, 120.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 113.8ms
# Speed: 0.0ms preprocess, 113.8ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 111.1ms
# Speed: 0.0ms preprocess, 111.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 114.8ms
# Speed: 0.0ms preprocess, 114.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 156.7ms
# Speed: 3.5ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 154.9ms
# Speed: 0.0ms preprocess, 154.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 125.2ms
# Speed: 2.9ms preprocess, 125.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 117.2ms
# Speed: 0.0ms preprocess, 117.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 111.8ms
# Speed: 0.0ms preprocess, 111.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 123.3ms
# Speed: 0.0ms preprocess, 123.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 110.4ms
# Speed: 0.0ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 112.7ms
# Speed: 0.0ms preprocess, 112.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 113.9ms
# Speed: 0.0ms preprocess, 113.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 114.8ms
# Speed: 4.2ms preprocess, 114.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 386.0ms
# Speed: 0.0ms preprocess, 386.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 400.7ms
# Speed: 0.0ms preprocess, 400.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 412.6ms
# Speed: 0.0ms preprocess, 412.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 367.6ms
# Speed: 9.0ms preprocess, 367.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 400.6ms
# Speed: 0.0ms preprocess, 400.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 400.1ms
# Speed: 0.0ms preprocess, 400.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 415.9ms
# Speed: 0.0ms preprocess, 415.9ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 400.6ms
# Speed: 0.0ms preprocess, 400.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 412.1ms
# Speed: 0.0ms preprocess, 412.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 399.1ms
# Speed: 0.0ms preprocess, 399.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 396.8ms
# Speed: 0.0ms preprocess, 396.8ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 415.2ms
# Speed: 0.0ms preprocess, 415.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 379.1ms
# Speed: 4.1ms preprocess, 379.1ms inference, 15.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 415.4ms
# Speed: 0.0ms preprocess, 415.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 368.3ms
# Speed: 0.0ms preprocess, 368.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 398.9ms
# Speed: 0.0ms preprocess, 398.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# ...
# Speed: 0.0ms preprocess, 382.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 415.4ms
# Speed: 0.0ms preprocess, 415.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 367.0ms
# Speed: 1.0ms preprocess, 367.0ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.1ms
# Speed: 0.0ms preprocess, 383.1ms inference, 16.2ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 407.2ms
# Speed: 6.0ms preprocess, 407.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 364.4ms
# Speed: 0.0ms preprocess, 364.4ms inference, 15.3ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 1 Board, 380.5ms
# Speed: 0.0ms preprocess, 380.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 429.3ms
# Speed: 0.0ms preprocess, 429.3ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 374.4ms
# Speed: 0.0ms preprocess, 374.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 384.2ms
# Speed: 0.0ms preprocess, 384.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 406.1ms
# Speed: 7.6ms preprocess, 406.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 382.3ms
# Speed: 0.0ms preprocess, 382.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 221.9ms
# Speed: 0.0ms preprocess, 221.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 384.3ms
# Speed: 13.4ms preprocess, 384.3ms inference, 15.4ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 389.9ms
# Speed: 0.0ms preprocess, 389.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.9ms
# Speed: 0.0ms preprocess, 383.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 401.1ms
# Speed: 0.0ms preprocess, 401.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 405.5ms
# Speed: 7.8ms preprocess, 405.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 379.8ms
# Speed: 0.0ms preprocess, 379.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 395.9ms
# Speed: 0.0ms preprocess, 395.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.8ms
# Speed: 0.0ms preprocess, 383.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 400.3ms
# Speed: 0.0ms preprocess, 400.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.6ms
# Speed: 0.0ms preprocess, 399.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 382.6ms
# Speed: 0.0ms preprocess, 382.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 397.6ms
# Speed: 0.0ms preprocess, 397.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.4ms
# Speed: 0.0ms preprocess, 399.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 402.0ms
# Speed: 0.0ms preprocess, 402.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 385.4ms
# Speed: 0.0ms preprocess, 385.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 398.5ms
# Speed: 0.0ms preprocess, 398.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 396.7ms
# Speed: 0.0ms preprocess, 396.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 382.5ms
# Speed: 0.0ms preprocess, 382.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 415.1ms
# Speed: 0.0ms preprocess, 415.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 400.7ms
# Speed: 0.0ms preprocess, 400.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 401.1ms
# Speed: 0.0ms preprocess, 401.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 397.5ms
# Speed: 0.0ms preprocess, 397.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 395.8ms
# Speed: 0.0ms preprocess, 395.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 375.1ms
# Speed: 4.8ms preprocess, 375.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 416.4ms
# Speed: 0.0ms preprocess, 416.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 368.5ms
# Speed: 0.0ms preprocess, 368.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 388.9ms
# Speed: 0.0ms preprocess, 388.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 406.6ms
# Speed: 0.0ms preprocess, 406.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 397.2ms
# Speed: 0.0ms preprocess, 397.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 397.2ms
# Speed: 0.0ms preprocess, 397.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.0ms
# Speed: 0.0ms preprocess, 399.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.8ms
# Speed: 0.0ms preprocess, 399.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 395.1ms
# Speed: 3.6ms preprocess, 395.1ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.0ms
# Speed: 0.0ms preprocess, 399.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 386.1ms
# Speed: 0.0ms preprocess, 386.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 397.9ms
# Speed: 0.0ms preprocess, 397.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 417.8ms
# Speed: 0.0ms preprocess, 417.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.0ms
# Speed: 0.0ms preprocess, 383.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 400.1ms
# Speed: 0.0ms preprocess, 400.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.8ms
# Speed: 0.0ms preprocess, 399.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 412.6ms
# Speed: 0.0ms preprocess, 412.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 396.9ms
# Speed: 0.0ms preprocess, 396.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.3ms
# Speed: 0.0ms preprocess, 399.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 400.3ms
# Speed: 0.0ms preprocess, 400.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.0ms
# Speed: 0.0ms preprocess, 383.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 334.3ms
# Speed: 0.0ms preprocess, 334.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 379.1ms
# Speed: 1.8ms preprocess, 379.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 399.5ms
# Speed: 0.0ms preprocess, 399.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 413.5ms
# Speed: 0.0ms preprocess, 413.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 400.4ms
# Speed: 0.0ms preprocess, 400.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 352.4ms
# Speed: 0.0ms preprocess, 352.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 406.4ms
# Speed: 7.6ms preprocess, 406.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 404.1ms
# Speed: 8.3ms preprocess, 404.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 382.0ms
# Speed: 0.0ms preprocess, 382.0ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 447.9ms
# Speed: 0.0ms preprocess, 447.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 379.9ms
# Speed: 2.0ms preprocess, 379.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 383.9ms
# Speed: 0.0ms preprocess, 383.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 381.7ms
# Speed: 0.0ms preprocess, 381.7ms inference, 14.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 376.6ms
# Speed: 5.2ms preprocess, 376.6ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 393.9ms
# Speed: 0.0ms preprocess, 393.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 412.6ms
# Speed: 0.0ms preprocess, 412.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 381.4ms
# Speed: 0.0ms preprocess, 381.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 396.9ms
# Speed: 0.0ms preprocess, 396.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 381.5ms
# Speed: 0.0ms preprocess, 381.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 1 Red, 2 Oranges, 1 Yellow, 2 Boards, 396.8ms
# Speed: 0.0ms preprocess, 396.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 396.8ms
# Speed: 0.0ms preprocess, 396.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 404.9ms
# Speed: 0.0ms preprocess, 404.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 398.6ms
# Speed: 0.0ms preprocess, 398.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 378.0ms
# Speed: 15.7ms preprocess, 378.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
#
# 0: 480x640 2 Reds, 2 Oranges, 1 Yellow, 2 Boards, 251.4ms
# Speed: 4.8ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# All present.
# Failed to read from Camera
# Stream timeout. Attempting to reconnect...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
# Error: Could not open video stream. Retrying in 5 seconds...
